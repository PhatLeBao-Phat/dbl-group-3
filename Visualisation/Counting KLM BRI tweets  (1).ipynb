# %%
import json 
import pandas as pd 
import numpy as np

# %%
df_database = pd.read_json('../data/airlines-1558527599826.json', lines=True)
df_database.head()
# Out:
#                  created_at            id        id_str  \
# 0 2019-05-22 12:20:00+00:00  1.131173e+18  1.131173e+18
# 1 2019-05-22 12:20:01+00:00  1.131173e+18  1.131173e+18
# 2 2019-05-22 12:20:02+00:00  1.131173e+18  1.131173e+18
# 3 2019-05-22 12:20:12+00:00  1.131173e+18  1.131173e+18
# 4 2019-05-22 12:20:28+00:00  1.131173e+18  1.131173e+18
#
#                                                 text display_text_range  \
# 0  La ruta de easyJet entre Londres y Menorca tra...           [0, 113]
# 1  RT @bttr_as1: @goody_tracy Here’s a list of so...                NaN
# 2                                   @British_Airways                NaN
# 3  RT @TheRaceRadio: Nice change by @AmericanAir....                NaN
# 4  RT @sandeeprrao1991: BREAKING:-\nKLM to fly 3x...                NaN
#
#                                               source  truncated  \
# 0  <a href="https://about.twitter.com/products/tw...        0.0
# ...

# %%
df_datas = df_database.dropna(subset = ["user"]).reset_index()
df_datas
# Out:
#        index                created_at            id        id_str  \
# 0          0 2019-05-22 12:20:00+00:00  1.131173e+18  1.131173e+18
# 1          1 2019-05-22 12:20:01+00:00  1.131173e+18  1.131173e+18
# 2          2 2019-05-22 12:20:02+00:00  1.131173e+18  1.131173e+18
# 3          3 2019-05-22 12:20:12+00:00  1.131173e+18  1.131173e+18
# 4          4 2019-05-22 12:20:28+00:00  1.131173e+18  1.131173e+18
# ...      ...                       ...           ...           ...
# 14382  14384 2019-05-23 11:42:26+00:00  1.131526e+18  1.131526e+18
# 14383  14385 2019-05-23 11:42:27+00:00  1.131526e+18  1.131526e+18
# 14384  14386 2019-05-23 11:42:27+00:00  1.131526e+18  1.131526e+18
# 14385  14387 2019-05-23 11:42:35+00:00  1.131526e+18  1.131526e+18
# 14386  14388 2019-05-23 11:42:44+00:00  1.131526e+18  1.131526e+18
#
#                                                     text display_text_range  \
# 0      La ruta de easyJet entre Londres y Menorca tra...           [0, 113]
# ...

# %%
#Counting how many tweets made by KLM,Bri (including posting+ replying to other):
count_made_klm = 0
count_made_bri = 0
for d in df_datas.user:
    if d.get("id_str") == "56377143":
        count_made_klm +=1
    if d.get("id_str") == "18332190":
        count_made_bri +=1
        
print(count_made_klm,count_made_bri)
# Out:
# 87 343

# %%
#Counting how many tweets mention KLM, Bri:
count_ment_klm = 0
count_ment_bri = 0

for d in df_datas.entities:
    for i in d.get("user_mentions"):
        if i.get("id_str") == "56377143":
            count_ment_klm +=1
        if i.get("id_str") == "18332190":
            count_ment_bri +=1
            
print(count_ment_klm,count_ment_bri)
# Out:
# 334 1770

# %%
#Extract only tweets made by KLM (including posting +replying to other):
test = df_datas.copy()

ind = []
for index, row in df_datas.iterrows():
    if row['user']['id_str'] == '56377143':
        ind.append(index)
klm_tweet = df_datas.iloc[ind]
klm_tweet.reset_index(inplace=True)
klm_tweet
# Out:
#     level_0  index                created_at            id        id_str  \
# 0        36     36 2019-05-22 12:23:03+00:00  1.131174e+18  1.131174e+18
# 1       635    635 2019-05-22 13:09:16+00:00  1.131185e+18  1.131185e+18
# 2       785    785 2019-05-22 13:20:05+00:00  1.131188e+18  1.131188e+18
# 3       788    788 2019-05-22 13:20:17+00:00  1.131188e+18  1.131188e+18
# 4       791    791 2019-05-22 13:20:31+00:00  1.131188e+18  1.131188e+18
# ..      ...    ...                       ...           ...           ...
# 82    13753  13755 2019-05-23 11:05:39+00:00  1.131517e+18  1.131517e+18
# 83    13916  13918 2019-05-23 11:15:59+00:00  1.131519e+18  1.131519e+18
# 84    13990  13992 2019-05-23 11:19:29+00:00  1.131520e+18  1.131520e+18
# 85    14030  14032 2019-05-23 11:21:36+00:00  1.131521e+18  1.131521e+18
# 86    14319  14321 2019-05-23 11:37:25+00:00  1.131525e+18  1.131525e+18
#
#                                                  text display_text_range  \
# ...

# %%
#Extract only tweets mention KLM (@KLM etc...):
test2 = df_datas.copy()
ind2 = []
for index, row in df_datas.iterrows():
    if "@KLM" in row['text']:
        ind2.append(index)
klm_tweet_men = df_datas.loc[ind2]
klm_tweet_men
# Out:
#        index                created_at            id        id_str  \
# 54        54 2019-05-22 12:24:26+00:00  1.131174e+18  1.131174e+18
# 55        55 2019-05-22 12:24:31+00:00  1.131174e+18  1.131174e+18
# 92        92 2019-05-22 12:27:15+00:00  1.131175e+18  1.131175e+18
# 173      173 2019-05-22 12:35:00+00:00  1.131177e+18  1.131177e+18
# 204      204 2019-05-22 12:37:29+00:00  1.131177e+18  1.131177e+18
# ...      ...                       ...           ...           ...
# 14260  14262 2019-05-23 11:34:10+00:00  1.131524e+18  1.131524e+18
# 14262  14264 2019-05-23 11:34:15+00:00  1.131524e+18  1.131524e+18
# 14293  14295 2019-05-23 11:36:09+00:00  1.131524e+18  1.131524e+18
# 14325  14327 2019-05-23 11:37:55+00:00  1.131525e+18  1.131525e+18
# 14342  14344 2019-05-23 11:39:01+00:00  1.131525e+18  1.131525e+18
#
#                                                     text display_text_range  \
# 54     RT @McWhirterAlex: .@KLM will fly Amsterdam-Ba...                NaN
# ...
