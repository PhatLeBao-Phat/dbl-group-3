# %%
df_database = pd.read_json('../data/airlines-1558527599826.json', lines=True)
df_datas = df_database.dropna(subset = ["user"])

# %%
test = df_datas.copy()

ind = []
for index, row in df_datas.iterrows():
    if row['user']['id_str'] == '56377143':
        ind.append(index)
klm_tweet = df_datas.loc[ind]

# %%
klm_tweet.head()
# Out:
#                    created_at            id        id_str  \
# 36  2019-05-22 12:23:03+00:00  1.131174e+18  1.131174e+18
# 635 2019-05-22 13:09:16+00:00  1.131185e+18  1.131185e+18
# 785 2019-05-22 13:20:05+00:00  1.131188e+18  1.131188e+18
# 788 2019-05-22 13:20:17+00:00  1.131188e+18  1.131188e+18
# 791 2019-05-22 13:20:31+00:00  1.131188e+18  1.131188e+18
#
#                                                   text display_text_range  \
# 36   @Pelusitaaaa1 Hoi!  Enkel KLM/Air France-vluch...          [14, 140]
# 635  @Pelusitaaaa1 We helpen je graag. Kan je ons e...          [14, 107]
# 785  @addblackman We understand that you would pref...          [13, 140]
# 788  @CarlosMosig Con el fin de evitar errores noso...          [13, 140]
# 791  @addblackman We do understand that some passen...          [13, 140]
#
#                                                 source  truncated  \
# 36   <a href="http://www.salesforce.com" rel="nofol...        1.0
# ...

# %%
klm_tweet[['id', 'id_str', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'timestamp_ms' ]]
# Out:
#                  id        id_str  in_reply_to_status_id  \
# 36     1.131174e+18  1.131174e+18           1.131171e+18
# 635    1.131185e+18  1.131185e+18           1.131183e+18
# 785    1.131188e+18  1.131188e+18           1.131182e+18
# 788    1.131188e+18  1.131188e+18           1.131183e+18
# 791    1.131188e+18  1.131188e+18           1.131182e+18
# ...             ...           ...                    ...
# 13755  1.131517e+18  1.131517e+18           1.131512e+18
# 13918  1.131519e+18  1.131519e+18           1.131517e+18
# 13992  1.131520e+18  1.131520e+18           1.131518e+18
# 14032  1.131521e+18  1.131521e+18           1.131519e+18
# 14321  1.131525e+18  1.131525e+18           1.131520e+18
#
#        in_reply_to_status_id_str  in_reply_to_user_id            timestamp_ms
# 36                  1.131171e+18         3.110269e+09 2019-05-22 12:23:03.108
# 635                 1.131183e+18         3.110269e+09 2019-05-22 13:09:16.877
# ...

# %%
a = klm_tweet['timestamp_ms'].iloc[1] - klm_tweet['timestamp_ms'].iloc[2]

# %%
a.seconds
# Out:
# 85751

# %%
ts_str = '2000-03-10 15:43:10'
ts = pd.to_datetime(ts_str)
print(ts)

ts_str_list = ['2000-03-10 15:43:10', '2000/03/10 15:44']
ts_list = pd.to_datetime(ts_str_list)
print(list(ts_list))
# Out:
# 2000-03-10 15:43:10
# [Timestamp('2000-03-10 15:43:10'), Timestamp('2000-03-10 15:44:00')]

# %%
klm_tweet.user
# Out:
# 36       {'id': 56377143, 'id_str': '56377143', 'name':...
# 635      {'id': 56377143, 'id_str': '56377143', 'name':...
# 785      {'id': 56377143, 'id_str': '56377143', 'name':...
# 788      {'id': 56377143, 'id_str': '56377143', 'name':...
# 791      {'id': 56377143, 'id_str': '56377143', 'name':...
#                                ...
# 13755    {'id': 56377143, 'id_str': '56377143', 'name':...
# 13918    {'id': 56377143, 'id_str': '56377143', 'name':...
# 13992    {'id': 56377143, 'id_str': '56377143', 'name':...
# 14032    {'id': 56377143, 'id_str': '56377143', 'name':...
# 14321    {'id': 56377143, 'id_str': '56377143', 'name':...
# Name: user, Length: 87, dtype: object
