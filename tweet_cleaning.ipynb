# %%
import pandas as pd
import json 
import numpy as np 
import re

# %%
df_tweets = pd.read_json('data/airlines-1558527599826.json', lines=True)
df_tweets
# Out:
#                      created_at            id        id_str  \
# 0     2019-05-22 12:20:00+00:00  1.131173e+18  1.131173e+18
# 1     2019-05-22 12:20:01+00:00  1.131173e+18  1.131173e+18
# 2     2019-05-22 12:20:02+00:00  1.131173e+18  1.131173e+18
# 3     2019-05-22 12:20:12+00:00  1.131173e+18  1.131173e+18
# 4     2019-05-22 12:20:28+00:00  1.131173e+18  1.131173e+18
# ...                         ...           ...           ...
# 14384 2019-05-23 11:42:26+00:00  1.131526e+18  1.131526e+18
# 14385 2019-05-23 11:42:27+00:00  1.131526e+18  1.131526e+18
# 14386 2019-05-23 11:42:27+00:00  1.131526e+18  1.131526e+18
# 14387 2019-05-23 11:42:35+00:00  1.131526e+18  1.131526e+18
# 14388 2019-05-23 11:42:44+00:00  1.131526e+18  1.131526e+18
#
#                                                     text display_text_range  \
# 0      La ruta de easyJet entre Londres y Menorca tra...           [0, 113]
# 1      RT @bttr_as1: @goody_tracy Here’s a list of so...                NaN
# ...

# %%
#getdata_try.info()

# %%
#def cleaner(text):
    #text = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", text)     
    #return text
#for i in range(len(df_tweets['text'].values)):
    #text = df_tweets['text'].iloc[i]
    #df_tweets['text'].iloc[i] = cleaner(text)
#df_tweets.to_json('data/airlines-1558527599826.json')

# %%
#df_tweets.duplicated(subset=['text'])

# %%
#remove duplicated tweets sent by users not KLM or Bri
df_tweets = df_tweets.dropna(subset=['user'])
du = df_tweets.duplicated(subset=['text'])
lst = []
duplicate_list = []
for index, values in du.items():
    if values == True:
        lst.append(index)

for i in lst:
    if (df_tweets.user[i]['id_str'] != '56377143') and (df_tweets.user[i]['id_str'] != '18332190'):
        df_tweets.drop(i,axis=0, inplace=True)
