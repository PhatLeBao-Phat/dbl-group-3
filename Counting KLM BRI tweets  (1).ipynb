# %%
import json 
import pandas as pd 
import numpy as np

# %%
df_database = pd.read_json('airlines-1558527599826.json', lines=True)
df_database
# Out:
#                      created_at            id        id_str  \
# 0     2019-05-22 12:20:00+00:00  1.131173e+18  1.131173e+18
# 1     2019-05-22 12:20:01+00:00  1.131173e+18  1.131173e+18
# 2     2019-05-22 12:20:02+00:00  1.131173e+18  1.131173e+18
# 3     2019-05-22 12:20:12+00:00  1.131173e+18  1.131173e+18
# 4     2019-05-22 12:20:28+00:00  1.131173e+18  1.131173e+18
# ...                         ...           ...           ...
# 14384 2019-05-23 11:42:26+00:00  1.131526e+18  1.131526e+18
# 14385 2019-05-23 11:42:27+00:00  1.131526e+18  1.131526e+18
# 14386 2019-05-23 11:42:27+00:00  1.131526e+18  1.131526e+18
# 14387 2019-05-23 11:42:35+00:00  1.131526e+18  1.131526e+18
# 14388 2019-05-23 11:42:44+00:00  1.131526e+18  1.131526e+18
#
#                                                     text display_text_range  \
# 0      La ruta de easyJet entre Londres y Menorca tra...           [0, 113]
# 1      RT @bttr_as1: @goody_tracy Here’s a list of so...                NaN
# 2                                       @British_Airways                NaN
# 3      RT @TheRaceRadio: Nice change by @AmericanAir....                NaN
# 4      RT @sandeeprrao1991: BREAKING:-\nKLM to fly 3x...                NaN
# ...                                                  ...                ...
# 14384     @yvettetravel were you invited to attend this?                NaN
# 14385  RT @RoyalFamily: The Queen sees how the @Briti...                NaN
# 14386  @RoyalSpectator @British_Airways She looks AMA...           [33, 60]
# 14387  @maj_fox @British_Airways Should happen more o...           [26, 94]
# 14388  @British_Airways delayed 5hrs on flight BA0103...                NaN
#
#                                                   source  truncated  \
# 0      <a href="https://about.twitter.com/products/tw...        0.0
# 1      <a href="http://twitter.com/download/iphone" r...        0.0
# 2      <a href="http://twitter.com/download/android" ...        0.0
# 3      <a href="http://twitter.com/download/android" ...        0.0
# 4      <a href="https://mobile.twitter.com" rel="nofo...        0.0
# ...                                                  ...        ...
# 14384  <a href="http://twitter.com/download/iphone" r...        0.0
# 14385  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 14386  <a href="http://twitter.com" rel="nofollow">Tw...        0.0
# 14387  <a href="http://twitter.com/download/android" ...        0.0
# 14388  <a href="http://twitter.com/download/iphone" r...        1.0
#
#        in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                        NaN                        NaN                  NaN
# 1                        NaN                        NaN                  NaN
# 2               1.131033e+18               1.131033e+18         3.943766e+08
# 3                        NaN                        NaN                  NaN
# 4                        NaN                        NaN                  NaN
# ...                      ...                        ...                  ...
# 14384                    NaN                        NaN         3.046262e+08
# 14385                    NaN                        NaN                  NaN
# 14386           1.131512e+18               1.131512e+18         1.590887e+09
# 14387           1.131484e+18               1.131484e+18         1.085556e+18
# 14388                    NaN                        NaN         1.833219e+07
#
#        ...  filter_level lang            timestamp_ms  \
# 0      ...           low   es 2019-05-22 12:20:00.406
# 1      ...           low   en 2019-05-22 12:20:01.645
# 2      ...           low  und 2019-05-22 12:20:02.560
# 3      ...           low   en 2019-05-22 12:20:12.449
# 4      ...           low   en 2019-05-22 12:20:28.237
# ...    ...           ...  ...                     ...
# 14384  ...           low   en 2019-05-23 11:42:26.066
# 14385  ...           low   en 2019-05-23 11:42:27.109
# 14386  ...           low   en 2019-05-23 11:42:27.469
# 14387  ...           low   en 2019-05-23 11:42:35.858
# 14388  ...           low   en 2019-05-23 11:42:44.440
#
#                                         retweeted_status  \
# 0                                                    NaN
# 1      {'created_at': 'Tue May 21 19:43:11 +0000 2019...
# 2                                                    NaN
# 3      {'created_at': 'Wed May 22 02:53:26 +0000 2019...
# 4      {'created_at': 'Wed May 22 12:10:24 +0000 2019...
# ...                                                  ...
# 14384                                                NaN
# 14385  {'created_at': 'Thu May 23 11:13:08 +0000 2019...
# 14386                                                NaN
# 14387                                                NaN
# 14388                                                NaN
#
#                                           extended_tweet quoted_status_id  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2                                                    NaN              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 14384                                                NaN     1.131507e+18
# 14385                                                NaN              NaN
# 14386                                                NaN              NaN
# 14387                                                NaN              NaN
# 14388  {'full_text': '@British_Airways delayed 5hrs o...              NaN
#
#        quoted_status_id_str  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 14384          1.131507e+18
# 14385                   NaN
# 14386                   NaN
# 14387                   NaN
# 14388                   NaN
#
#                                            quoted_status  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14384  {'created_at': 'Thu May 23 10:28:34 +0000 2019...
# 14385                                                NaN
# 14386                                                NaN
# 14387                                                NaN
# 14388                                                NaN
#
#                                  quoted_status_permalink  delete
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 14384  {'url': 'https://t.co/iLnuh7ejub', 'expanded':...     NaN
# 14385                                                NaN     NaN
# 14386                                                NaN     NaN
# 14387                                                NaN     NaN
# 14388                                                NaN     NaN
#
# [14389 rows x 37 columns]

# %%
df_datas = df_database.dropna(subset = ["user"])
df_datas
# Out:
#                      created_at            id        id_str  \
# 0     2019-05-22 12:20:00+00:00  1.131173e+18  1.131173e+18
# 1     2019-05-22 12:20:01+00:00  1.131173e+18  1.131173e+18
# 2     2019-05-22 12:20:02+00:00  1.131173e+18  1.131173e+18
# 3     2019-05-22 12:20:12+00:00  1.131173e+18  1.131173e+18
# 4     2019-05-22 12:20:28+00:00  1.131173e+18  1.131173e+18
# ...                         ...           ...           ...
# 14384 2019-05-23 11:42:26+00:00  1.131526e+18  1.131526e+18
# 14385 2019-05-23 11:42:27+00:00  1.131526e+18  1.131526e+18
# 14386 2019-05-23 11:42:27+00:00  1.131526e+18  1.131526e+18
# 14387 2019-05-23 11:42:35+00:00  1.131526e+18  1.131526e+18
# 14388 2019-05-23 11:42:44+00:00  1.131526e+18  1.131526e+18
#
#                                                     text display_text_range  \
# 0      La ruta de easyJet entre Londres y Menorca tra...           [0, 113]
# 1      RT @bttr_as1: @goody_tracy Here’s a list of so...                NaN
# 2                                       @British_Airways                NaN
# 3      RT @TheRaceRadio: Nice change by @AmericanAir....                NaN
# 4      RT @sandeeprrao1991: BREAKING:-\nKLM to fly 3x...                NaN
# ...                                                  ...                ...
# 14384     @yvettetravel were you invited to attend this?                NaN
# 14385  RT @RoyalFamily: The Queen sees how the @Briti...                NaN
# 14386  @RoyalSpectator @British_Airways She looks AMA...           [33, 60]
# 14387  @maj_fox @British_Airways Should happen more o...           [26, 94]
# 14388  @British_Airways delayed 5hrs on flight BA0103...                NaN
#
#                                                   source  truncated  \
# 0      <a href="https://about.twitter.com/products/tw...        0.0
# 1      <a href="http://twitter.com/download/iphone" r...        0.0
# 2      <a href="http://twitter.com/download/android" ...        0.0
# 3      <a href="http://twitter.com/download/android" ...        0.0
# 4      <a href="https://mobile.twitter.com" rel="nofo...        0.0
# ...                                                  ...        ...
# 14384  <a href="http://twitter.com/download/iphone" r...        0.0
# 14385  <a href="https://mobile.twitter.com" rel="nofo...        0.0
# 14386  <a href="http://twitter.com" rel="nofollow">Tw...        0.0
# 14387  <a href="http://twitter.com/download/android" ...        0.0
# 14388  <a href="http://twitter.com/download/iphone" r...        1.0
#
#        in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  \
# 0                        NaN                        NaN                  NaN
# 1                        NaN                        NaN                  NaN
# 2               1.131033e+18               1.131033e+18         3.943766e+08
# 3                        NaN                        NaN                  NaN
# 4                        NaN                        NaN                  NaN
# ...                      ...                        ...                  ...
# 14384                    NaN                        NaN         3.046262e+08
# 14385                    NaN                        NaN                  NaN
# 14386           1.131512e+18               1.131512e+18         1.590887e+09
# 14387           1.131484e+18               1.131484e+18         1.085556e+18
# 14388                    NaN                        NaN         1.833219e+07
#
#        ...  filter_level lang            timestamp_ms  \
# 0      ...           low   es 2019-05-22 12:20:00.406
# 1      ...           low   en 2019-05-22 12:20:01.645
# 2      ...           low  und 2019-05-22 12:20:02.560
# 3      ...           low   en 2019-05-22 12:20:12.449
# 4      ...           low   en 2019-05-22 12:20:28.237
# ...    ...           ...  ...                     ...
# 14384  ...           low   en 2019-05-23 11:42:26.066
# 14385  ...           low   en 2019-05-23 11:42:27.109
# 14386  ...           low   en 2019-05-23 11:42:27.469
# 14387  ...           low   en 2019-05-23 11:42:35.858
# 14388  ...           low   en 2019-05-23 11:42:44.440
#
#                                         retweeted_status  \
# 0                                                    NaN
# 1      {'created_at': 'Tue May 21 19:43:11 +0000 2019...
# 2                                                    NaN
# 3      {'created_at': 'Wed May 22 02:53:26 +0000 2019...
# 4      {'created_at': 'Wed May 22 12:10:24 +0000 2019...
# ...                                                  ...
# 14384                                                NaN
# 14385  {'created_at': 'Thu May 23 11:13:08 +0000 2019...
# 14386                                                NaN
# 14387                                                NaN
# 14388                                                NaN
#
#                                           extended_tweet quoted_status_id  \
# 0                                                    NaN              NaN
# 1                                                    NaN              NaN
# 2                                                    NaN              NaN
# 3                                                    NaN              NaN
# 4                                                    NaN              NaN
# ...                                                  ...              ...
# 14384                                                NaN     1.131507e+18
# 14385                                                NaN              NaN
# 14386                                                NaN              NaN
# 14387                                                NaN              NaN
# 14388  {'full_text': '@British_Airways delayed 5hrs o...              NaN
#
#        quoted_status_id_str  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
# ...                     ...
# 14384          1.131507e+18
# 14385                   NaN
# 14386                   NaN
# 14387                   NaN
# 14388                   NaN
#
#                                            quoted_status  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 14384  {'created_at': 'Thu May 23 10:28:34 +0000 2019...
# 14385                                                NaN
# 14386                                                NaN
# 14387                                                NaN
# 14388                                                NaN
#
#                                  quoted_status_permalink  delete
# 0                                                    NaN     NaN
# 1                                                    NaN     NaN
# 2                                                    NaN     NaN
# 3                                                    NaN     NaN
# 4                                                    NaN     NaN
# ...                                                  ...     ...
# 14384  {'url': 'https://t.co/iLnuh7ejub', 'expanded':...     NaN
# 14385                                                NaN     NaN
# 14386                                                NaN     NaN
# 14387                                                NaN     NaN
# 14388                                                NaN     NaN
#
# [14387 rows x 37 columns]

# %%
#Counting how many tweets made by KLM,Bri (including posting+ replying to other):
count_made_klm = 0
count_made_bri = 0
for d in df_datas.user:
    if d.get("id_str") == "56377143":
        count_made_klm +=1
    if d.get("id_str") == "18332190":
        count_made_bri +=1
        
print(count_made_klm,count_made_bri)
# Out:
# 87 343

# %%
#Counting how many tweets mention KLM, Bri:
count_ment_klm = 0
count_ment_bri = 0

for d in df_datas.entities:
    for i in d.get("user_mentions"):
        if i.get("id_str") == "56377143":
            count_ment_klm +=1
        if i.get("id_str") == "18332190":
            count_ment_bri +=1
            
print(count_ment_klm,count_ment_bri)
# Out:
# 334 1770

# %%
#Extract only tweets made by KLM (including posting +replying to other):
test = df_datas.copy()

ind = []
for index, row in df_datas.iterrows():
    if row['user']['id_str'] == '56377143':
        ind.append(index)
klm_tweet = df_datas.iloc[ind]
klm_tweet
# Out:
#                      created_at            id        id_str  \
# 36    2019-05-22 12:23:03+00:00  1.131174e+18  1.131174e+18
# 635   2019-05-22 13:09:16+00:00  1.131185e+18  1.131185e+18
# 785   2019-05-22 13:20:05+00:00  1.131188e+18  1.131188e+18
# 788   2019-05-22 13:20:17+00:00  1.131188e+18  1.131188e+18
# 791   2019-05-22 13:20:31+00:00  1.131188e+18  1.131188e+18
# ...                         ...           ...           ...
# 13757 2019-05-23 11:05:55+00:00  1.131517e+18  1.131517e+18
# 13920 2019-05-23 11:16:04+00:00  1.131519e+18  1.131519e+18
# 13994 2019-05-23 11:19:49+00:00  1.131520e+18  1.131520e+18
# 14034 2019-05-23 11:21:45+00:00  1.131521e+18  1.131521e+18
# 14323 2019-05-23 11:37:28+00:00  1.131525e+18  1.131525e+18
#
#                                                     text display_text_range  \
# 36     @Pelusitaaaa1 Hoi!  Enkel KLM/Air France-vluch...          [14, 140]
# 635    @Pelusitaaaa1 We helpen je graag. Kan je ons e...          [14, 107]
# 785    @addblackman We understand that you would pref...          [13, 140]
# 788    @CarlosMosig Con el fin de evitar errores noso...          [13, 140]
# 791    @addblackman We do understand that some passen...          [13, 140]
# ...                                                  ...                ...
# 13757  RT @RoyalFamily: The Queen arrives at @British...                NaN
# 13920             @AmericanAir Well done &amp; THANK YOU           [13, 38]
# 13994  @RoyalFamily @British_Airways The Queen looks ...           [30, 71]
# 14034  RT @RoyalFamily: The Queen sees how the @Briti...                NaN
# 14323  RT @veriterdeh: Ptdrrr chui morte l’histoire d...                NaN
#
#                                                   source  truncated  \
# 36     <a href="http://www.salesforce.com" rel="nofol...        1.0
# 635    <a href="http://www.salesforce.com" rel="nofol...        0.0
# 785    <a href="http://www.salesforce.com" rel="nofol...        1.0
# 788    <a href="http://www.salesforce.com" rel="nofol...        1.0
# 791    <a href="http://www.salesforce.com" rel="nofol...        1.0
# ...                                                  ...        ...
# 13757  <a href="http://twitter.com/download/iphone" r...        0.0
# 13920  <a href="http://twitter.com/download/iphone" r...        0.0
# 13994  <a href="http://twitter.com" rel="nofollow">Tw...        0.0
# 14034  <a href="http://www.twitter.com" rel="nofollow...        0.0
# 14323  <a href="http://twitter.com/download/iphone" r...        0.0
#
#        in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  \
# 36              1.131171e+18               1.131171e+18         3.110269e+09
# 635             1.131183e+18               1.131183e+18         3.110269e+09
# 785             1.131182e+18               1.131182e+18         1.604219e+09
# 788             1.131183e+18               1.131183e+18         8.794935e+17
# 791             1.131182e+18               1.131182e+18         1.604219e+09
# ...                      ...                        ...                  ...
# 13757                    NaN                        NaN                  NaN
# 13920           1.130940e+18               1.130940e+18         2.253606e+07
# 13994           1.131518e+18               1.131518e+18         3.604255e+07
# 14034                    NaN                        NaN                  NaN
# 14323                    NaN                        NaN                  NaN
#
#        ...  filter_level lang            timestamp_ms  \
# 36     ...           low   nl 2019-05-22 12:23:03.108
# 635    ...           low   nl 2019-05-22 13:09:16.877
# 785    ...           low   en 2019-05-22 13:20:05.252
# 788    ...           low   es 2019-05-22 13:20:17.115
# 791    ...           low   en 2019-05-22 13:20:31.611
# ...    ...           ...  ...                     ...
# 13757  ...           low   en 2019-05-23 11:05:55.791
# 13920  ...           low   en 2019-05-23 11:16:04.314
# 13994  ...           low   en 2019-05-23 11:19:49.619
# 14034  ...           low   en 2019-05-23 11:21:45.950
# 14323  ...           low   fr 2019-05-23 11:37:28.643
#
#                                         retweeted_status  \
# 36                                                   NaN
# 635                                                  NaN
# 785                                                  NaN
# 788                                                  NaN
# 791                                                  NaN
# ...                                                  ...
# 13757  {'created_at': 'Thu May 23 10:28:34 +0000 2019...
# 13920                                                NaN
# 13994                                                NaN
# 14034  {'created_at': 'Thu May 23 11:13:08 +0000 2019...
# 14323  {'created_at': 'Wed May 22 14:26:24 +0000 2019...
#
#                                           extended_tweet quoted_status_id  \
# 36     {'full_text': '@Pelusitaaaa1 Hoi!  Enkel KLM/A...              NaN
# 635                                                  NaN              NaN
# 785    {'full_text': '@addblackman We understand that...              NaN
# 788    {'full_text': '@CarlosMosig Con el fin de evit...              NaN
# 791    {'full_text': '@addblackman We do understand t...              NaN
# ...                                                  ...              ...
# 13757                                                NaN              NaN
# 13920                                                NaN              NaN
# 13994                                                NaN              NaN
# 14034                                                NaN              NaN
# 14323                                                NaN              NaN
#
#        quoted_status_id_str  quoted_status  quoted_status_permalink  delete
# 36                      NaN            NaN                      NaN     NaN
# 635                     NaN            NaN                      NaN     NaN
# 785                     NaN            NaN                      NaN     NaN
# 788                     NaN            NaN                      NaN     NaN
# 791                     NaN            NaN                      NaN     NaN
# ...                     ...            ...                      ...     ...
# 13757                   NaN            NaN                      NaN     NaN
# 13920                   NaN            NaN                      NaN     NaN
# 13994                   NaN            NaN                      NaN     NaN
# 14034                   NaN            NaN                      NaN     NaN
# 14323                   NaN            NaN                      NaN     NaN
#
# [87 rows x 37 columns]

# %%
#Extract only tweets mention KLM (@KLM etc...):
test2 = df_datas.copy()
ind2 = []
for index, row in df_datas.iterrows():
    if "@KLM" in row['text']:
        ind2.append(index)
klm_tweet_men = df_datas.iloc[ind2]
klm_tweet_men
# Out:
#                      created_at            id        id_str  \
# 54    2019-05-22 12:24:26+00:00  1.131174e+18  1.131174e+18
# 55    2019-05-22 12:24:31+00:00  1.131174e+18  1.131174e+18
# 92    2019-05-22 12:27:15+00:00  1.131175e+18  1.131175e+18
# 173   2019-05-22 12:35:00+00:00  1.131177e+18  1.131177e+18
# 204   2019-05-22 12:37:29+00:00  1.131177e+18  1.131177e+18
# ...                         ...           ...           ...
# 14264 2019-05-23 11:34:15+00:00  1.131524e+18  1.131524e+18
# 14266 2019-05-23 11:34:21+00:00  1.131524e+18  1.131524e+18
# 14297 2019-05-23 11:36:21+00:00  1.131524e+18  1.131524e+18
# 14329 2019-05-23 11:38:05+00:00  1.131525e+18  1.131525e+18
# 14346 2019-05-23 11:39:06+00:00  1.131525e+18  1.131525e+18
#
#                                                     text display_text_range  \
# 54     RT @McWhirterAlex: .@KLM will fly Amsterdam-Ba...                NaN
# 55     RT @Vinamralongani: @KLM to launch thrice week...                NaN
# 92                         @wolfmandanny @KLM Thanks Dan           [19, 29]
# 173    Waar @KLM de slots vandaan haalt is (nog) niet...                NaN
# 204    @KLM Aviation releases about 3% of human carbo...           [5, 124]
# ...                                                  ...                ...
# 14264             @markbrouwer2010 @KLM Ga toch fietsen!           [22, 38]
# 14266  RT @RoyalFamily: The Queen arrives at @British...                NaN
# 14297  @kwfrazie We do our best to keep cancellations...          [10, 140]
# 14329  RT @RoyalFamily: The Queen arrives at @British...                NaN
# 14346  RT @ChrisJack_Getty: Good Morning! I’m at @Bri...                NaN
#
#                                                   source  truncated  \
# 54     <a href="http://twitter.com/download/iphone" r...        0.0
# 55     <a href="http://twitter.com/download/iphone" r...        0.0
# 92     <a href="http://twitter.com/download/iphone" r...        0.0
# 173    <a href="http://twitter.com/#!/download/ipad" ...        0.0
# 204    <a href="https://mobile.twitter.com" rel="nofo...        0.0
# ...                                                  ...        ...
# 14264  <a href="http://twitter.com/download/iphone" r...        0.0
# 14266  <a href="http://twitter.com/download/android" ...        0.0
# 14297  <a href="http://ivoucher.aa.com/snap" rel="nof...        1.0
# 14329  <a href="http://twitter.com" rel="nofollow">Tw...        0.0
# 14346  <a href="http://twitter.com/download/iphone" r...        0.0
#
#        in_reply_to_status_id  in_reply_to_status_id_str  in_reply_to_user_id  \
# 54                       NaN                        NaN                  NaN
# 55                       NaN                        NaN                  NaN
# 92              1.131164e+18               1.131164e+18         2.784159e+09
# 173                      NaN                        NaN                  NaN
# 204             1.111660e+18               1.111660e+18         5.637714e+07
# ...                      ...                        ...                  ...
# 14264           1.131292e+18               1.131292e+18         1.546781e+08
# 14266                    NaN                        NaN                  NaN
# 14297           1.131521e+18               1.131521e+18         2.566225e+08
# 14329                    NaN                        NaN                  NaN
# 14346                    NaN                        NaN                  NaN
#
#        ...  filter_level lang            timestamp_ms  \
# 54     ...           low   en 2019-05-22 12:24:26.336
# 55     ...           low   en 2019-05-22 12:24:31.580
# 92     ...           low   en 2019-05-22 12:27:15.180
# 173    ...           low   nl 2019-05-22 12:35:00.067
# 204    ...           low   en 2019-05-22 12:37:29.913
# ...    ...           ...  ...                     ...
# 14264  ...           low   nl 2019-05-23 11:34:15.962
# 14266  ...           low   en 2019-05-23 11:34:21.282
# 14297  ...           low   en 2019-05-23 11:36:21.583
# 14329  ...           low   en 2019-05-23 11:38:05.993
# 14346  ...           low   en 2019-05-23 11:39:06.071
#
#                                         retweeted_status  \
# 54     {'created_at': 'Wed May 22 11:49:14 +0000 2019...
# 55     {'created_at': 'Wed May 22 11:52:42 +0000 2019...
# 92                                                   NaN
# 173                                                  NaN
# 204                                                  NaN
# ...                                                  ...
# 14264                                                NaN
# 14266  {'created_at': 'Thu May 23 10:28:34 +0000 2019...
# 14297                                                NaN
# 14329  {'created_at': 'Thu May 23 10:28:34 +0000 2019...
# 14346  {'created_at': 'Thu May 23 08:24:15 +0000 2019...
#
#                                           extended_tweet quoted_status_id  \
# 54                                                   NaN              NaN
# 55                                                   NaN              NaN
# 92                                                   NaN              NaN
# 173                                                  NaN     1.131160e+18
# 204                                                  NaN              NaN
# ...                                                  ...              ...
# 14264                                                NaN              NaN
# 14266                                                NaN              NaN
# 14297  {'full_text': '@kwfrazie We do our best to kee...              NaN
# 14329                                                NaN              NaN
# 14346                                                NaN              NaN
#
#        quoted_status_id_str  \
# 54                      NaN
# 55                      NaN
# 92                      NaN
# 173            1.131160e+18
# 204                     NaN
# ...                     ...
# 14264                   NaN
# 14266                   NaN
# 14297                   NaN
# 14329                   NaN
# 14346                   NaN
#
#                                            quoted_status  \
# 54                                                   NaN
# 55                                                   NaN
# 92                                                   NaN
# 173    {'created_at': 'Wed May 22 11:28:04 +0000 2019...
# 204                                                  NaN
# ...                                                  ...
# 14264                                                NaN
# 14266                                                NaN
# 14297                                                NaN
# 14329                                                NaN
# 14346                                                NaN
#
#                                  quoted_status_permalink  delete
# 54                                                   NaN     NaN
# 55                                                   NaN     NaN
# 92                                                   NaN     NaN
# 173    {'url': 'https://t.co/GwwWYOYj61', 'expanded':...     NaN
# 204                                                  NaN     NaN
# ...                                                  ...     ...
# 14264                                                NaN     NaN
# 14266                                                NaN     NaN
# 14297                                                NaN     NaN
# 14329                                                NaN     NaN
# 14346                                                NaN     NaN
#
# [334 rows x 37 columns]
